# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Heart.csv")
data
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
data.isna().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            4
# Thal          2
# AHD           0
# dtype: int64

# %%
mean=data["Ca"].mean()

# %%
data[data["Ca"].isna()]
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 166         167   52    1    nonanginal     138   223    0        0    169
# 192         193   43    1  asymptomatic     132   247    1        2    143
# 287         288   58    1    nontypical     125   220    0        0    144
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope  Ca        Thal  AHD
# 166      0      0.0      1 NaN      normal   No
# 192      1      0.1      2 NaN  reversable  Yes
# 287      0      0.4      2 NaN  reversable   No
# 302      0      0.0      1 NaN      normal   No

# %%
data[data["Thal"].isna()]
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 87           88   53    0    nonanginal     128   216    0        2    115
# 266         267   52    1  asymptomatic     128   204    1        0    156
#
#      ExAng  Oldpeak  Slope   Ca Thal  AHD
# 87       0      0.0      1  0.0  NaN   No
# 266      1      1.0      2  0.0  NaN  Yes

# %%
data.dropna(inplace=True) #drop

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 297 entries, 0 to 301
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  297 non-null    int64
#  1   Age         297 non-null    int64
#  2   Sex         297 non-null    int64
#  3   ChestPain   297 non-null    object
#  4   RestBP      297 non-null    int64
#  5   Chol        297 non-null    int64
#  6   Fbs         297 non-null    int64
#  7   RestECG     297 non-null    int64
#  8   MaxHR       297 non-null    int64
#  9   ExAng       297 non-null    int64
#  10  Oldpeak     297 non-null    float64
#  11  Slope       297 non-null    int64
#  12  Ca          297 non-null    float64
#  13  Thal        297 non-null    object
#  14  AHD         297 non-null    object
# dtypes: float64(2), int64(10), object(3)
# memory usage: 37.1+ KB

# %%
data.describe()
# Out:
#        Unnamed: 0         Age         Sex      RestBP        Chol         Fbs  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean   150.673401   54.542088    0.676768  131.693603  247.350168    0.144781
# std     87.323283    9.049736    0.468500   17.762806   51.997583    0.352474
# min      1.000000   29.000000    0.000000   94.000000  126.000000    0.000000
# 25%     75.000000   48.000000    0.000000  120.000000  211.000000    0.000000
# 50%    150.000000   56.000000    1.000000  130.000000  243.000000    0.000000
# 75%    226.000000   61.000000    1.000000  140.000000  276.000000    0.000000
# max    302.000000   77.000000    1.000000  200.000000  564.000000    1.000000
#
#           RestECG       MaxHR       ExAng     Oldpeak       Slope          Ca
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean     0.996633  149.599327    0.326599    1.055556    1.602694    0.676768
# ...

# %%
data["ChestPain"].nunique()
# Out:
# 4

# %%
data["Thal"].nunique()
# Out:
# 3

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
data["ChestPain"]=le.fit_transform(data["ChestPain"])
data["Thal"]=le.fit_transform(data["Thal"])

# %%
data
# Out:
#      Unnamed: 0  Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1          3     145   233    1        2    150
# 1             2   67    1          0     160   286    0        2    108
# 2             3   67    1          0     120   229    0        2    129
# 3             4   37    1          1     130   250    0        0    187
# 4             5   41    0          2     130   204    0        2    172
# ..          ...  ...  ...        ...     ...   ...  ...      ...    ...
# 297         298   57    0          0     140   241    0        0    123
# 298         299   45    1          3     110   264    0        0    132
# 299         300   68    1          0     144   193    1        0    141
# 300         301   57    1          0     130   131    0        0    115
# 301         302   57    0          2     130   236    0        2    174
#
#      ExAng  Oldpeak  Slope   Ca  Thal  AHD
# 0        0      2.3      3  0.0     0   No
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data=data.drop('AHD',axis=1).corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

# %%
x=data.iloc[:,:14]
y=data.iloc[:,14]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
train_pred=rf.predict(x_train)

# %%
test_pred=rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_train,train_pred)
# Out:
# 1.0

# %%
accuracy_score(y_test,test_pred)
# Out:
# 0.8833333333333333

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={"n_estimators":[50,100,150]}

# %%
gsv=GridSearchCV(estimator=rf,param_grid=parameters,scoring="accuracy",return_train_score=True)
gsv.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'n_estimators': [50, 100, 150]},
#              return_train_score=True, scoring='accuracy')

# %%
gsv.cv_results_
# Out:
# {'mean_fit_time': array([0.07691021, 0.1595336 , 0.20333114]),
#  'std_fit_time': array([0.0116572 , 0.02735889, 0.01728254]),
#  'mean_score_time': array([0.00542221, 0.01114349, 0.01642704]),
#  'std_score_time': array([0.00140186, 0.00269138, 0.0040062 ]),
#  'param_n_estimators': masked_array(data=[50, 100, 150],
#               mask=[False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'n_estimators': 50},
#   {'n_estimators': 100},
#   {'n_estimators': 150}],
#  'split0_test_score': array([0.8125, 0.8125, 0.8125]),
#  'split1_test_score': array([0.79166667, 0.8125    , 0.79166667]),
#  'split2_test_score': array([0.63829787, 0.74468085, 0.76595745]),
#  'split3_test_score': array([0.78723404, 0.72340426, 0.70212766]),
#  'split4_test_score': array([0.85106383, 0.85106383, 0.91489362]),
#  'mean_test_score': array([0.77615248, 0.78882979, 0.79742908]),
#  'std_test_score': array([0.07252618, 0.04737776, 0.06947097]),
# ...

# %%
gsv.best_params_
# Out:
# {'n_estimators': 150}
